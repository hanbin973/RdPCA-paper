# %%
library(Matrix)

# %%
meta <- read.csv('../../data/fucci/meta.csv', row.names=1)

# %%
fit <-smooth.spline(meta$theta, meta$nCount_RNA,df=7)
plot(meta$theta, meta$nCount_RNA)
lines(fit, col='red',lwd=2)
# Out:
# plot without title

# %%
df <- data.frame(x=fit$x, y=fit$y)
write.csv(df, 'fig1b.csv')
